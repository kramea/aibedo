# %%
from interpolate import *
import xarray as xr
path = "compress.isosph.CESM2.historical.r1i1p1f1.Input.Exp8_fixed.nc"
ds = xr.open_dataset(path)
data = np.asarray(ds.cres_pre[0])
lon_list = list(np.asarray(ds.cres_pre[0].lon))
lat_list = list(np.asarray(ds.cres_pre[0].lat))

# %%
lon, lat, interpolated_value = lon_list, lat_list, data

# %%
print(len(interpolated_value))
# Out:
# 40962

# %%
plt.scatter(lon[:42], lat[:42], marker='.')

# %%
plt.clf()
plt.scatter(lon, lat, marker='.')
i=1
for x,y in zip(lon,lat):
    label = "{}".format(i)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
    i = i+1
plt.show()

# %%
lon, lat, interpolated_value = interpolate_SphereIcosahedral( 2, data, lon_list, lat_list)
lon1, lat1, interpolated_value1 = interpolate_SphereIcosahedral( 1, data, lon_list, lat_list)

# %%
print(len(interpolated_value))
# Out:
# 162

# %%
plt.clf()
plt.scatter(lon, lat, marker='.', c="red")
plt.scatter(lon1, lat1, marker='.')
plt.show()

# %%
plt.clf()
plt.scatter(lon, lat, marker='.', c="red", s=150) #1
plt.scatter(lon1, lat1, marker='.') #2
i=1
for x,y in zip(lon1,lat1):
    label = "{}".format(i)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
    i = i+1
plt.show()

# %%
plt.clf()
plt.scatter(lon[:42], lat[:42], marker='.', c="red", s=150) #1
plt.scatter(lon[42:], lat[42:], marker='.', c="blue") #1
i=1
for x,y in zip(lon,lat):
    label = "{}".format(i)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
    i = i+1
plt.show()
