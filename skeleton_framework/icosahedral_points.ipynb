# %%
from interpolate import *
import xarray as xr
path = "/Users/sookim/Desktop/aibedo_sunet/aibedo/skeleton_framework/data/Exp1_ANN_CESM2_r1i1p1f1_historical_Input.nc"
ds = xr.open_dataset(path)
data = np.asarray(ds.cres_pre[0])
lon_list = list(np.asarray(ds.cres_pre[0].lon))
lat_list = list(np.asarray(ds.cres_pre[0].lat))

# %%
lon, lat, interpolated_value = interpolate_SphereIcosahedral( 1, data, lon_list, lat_list)

# %%
print(len(interpolated_value))
# Out:
# 42

# %%
plt.scatter(lon, lat, marker='.')

# %%
plt.clf()
plt.scatter(lon, lat, marker='.')
i=1
for x,y in zip(lon,lat):
    label = "{}".format(i)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
    i = i+1
plt.show()
