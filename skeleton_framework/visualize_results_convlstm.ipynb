# %%
import numpy as np
gt = np.load("/Users/sookim/Desktop/aibedo_sunet/aibedo/skeleton_framework/saved_model_convlstm/groundtruth_10_tensor(0.0175).npy")
pr = np.load("/Users/sookim/Desktop/aibedo_sunet/aibedo/skeleton_framework/saved_model_convlstm/prediction_10_tensor(0.0175).npy")
print(np.shape(gt), np.shape(pr)) #psl channel
# Out:
# (98, 10, 1, 40962) (98, 10, 1, 40962)

# %%
def mse(a1, a2):
    se = np.square(np.subtract(a1,a2))
    mse = se.mean()
    return mse

# %%
ch =['tas', 'psl', 'pr']
i=1 #channel
print(ch[i],": mse = ",mse(gt[:,-1,:,:], pr[:,-1,:,:]))
# Out:
# psl : mse =  0.017622626676179247

# %%
gt = gt[:,-1,:,:]; pr = pr[:,-1,:,:]

# %%
print(np.shape(gt), np.shape(pr)) #psl channel
# Out:
# (98, 1, 40962) (98, 1, 40962)

# %%
gt = np.swapaxes(gt, 1,2)

# %%
pr = np.swapaxes(pr, 1,2)

# %%
print(np.shape(gt), np.shape(pr))
# Out:
# (98, 40962, 1) (98, 40962, 1)

# %%
from interpolate import *

# %%
import cartopy.crs as ccrs
import xarray as xr

path = "/Users/sookim/Desktop/aibedo_sunet/aibedo/skeleton_framework/data/"
inn = xr.open_dataset(path+"Processed_CESM2_r1i1p1f1_historical_Input.nc")
inn['time'][:5]
# Out:
# <xarray.DataArray 'time' (time: 5)>
# array([cftime.DatetimeNoLeap(1850, 1, 15, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1850, 2, 14, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1850, 3, 15, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1850, 4, 15, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1850, 5, 15, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 1850-01-15 12:00:00 ... 1850-05-15 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     standard_name:  time
#     title:          time
#     type:           double

# %%
lon = np.load('lon.npy')
lat = np.load('lat.npy')

# %%
def visualize_2d_all(gt, pr, longitude, latitude, title, export_path=None):
    """Visualize the data on a 2D map

    Args:
        x (numpy.array): numpy array with data the size of the longitude and latitude
        longitude (numpy.array): longitude coordinates
        latitude (numpy.array): latitude coordinates
        export_path (string): path and name for saving
    """

    fig = plt.figure(figsize=(70, 10))
    ax = fig.add_subplot(1, 3, 1, projection=ccrs.PlateCarree())
    ax.set_global()
    ax.coastlines()

    plt.subplot(1, 3, 1)
    plt.scatter(longitude, latitude, s=20, c=gt, cmap=plt.get_cmap("RdYlBu_r"), alpha=1)
    plt.clim(0, 1)
    plt.xticks([-180,-90, 0,+90, 180])
    plt.yticks([-90,-45,0,45,90])
    plt.title("ground truth "+title)
    plt.colorbar(cmap=plt.get_cmap("RdYlBu_r"),fraction=0.046, pad=0.04)

    ax = fig.add_subplot(1, 3, 2, projection=ccrs.PlateCarree())
    ax.set_global()
    ax.coastlines()
    
    plt.subplot(1, 3, 2)
    plt.scatter(longitude, latitude, s=20, c=pr, cmap=plt.get_cmap("RdYlBu_r"), alpha=1)
    plt.xticks([-180,-90, 0,+90, 180])
    plt.yticks([-90,-45,0,45,90])
    plt.clim(0, 1)
    plt.title("prediction "+title)
    plt.colorbar(cmap=plt.get_cmap("RdYlBu_r"),fraction=0.046, pad=0.04)
    
    ax = fig.add_subplot(1, 3, 3, projection=ccrs.PlateCarree())
    ax.set_global()
    ax.coastlines()
    
    plt.subplot(1, 3, 3)
    plt.scatter(longitude, latitude, s=20, c=gt-pr, cmap=plt.get_cmap("RdYlBu_r"), alpha=1)
    plt.xticks([-180,-90, 0,+90, 180])
    plt.yticks([-90,-45,0,45,90])
    plt.clim(-1, 1)
    plt.title("error (gt-pr)"+title)
    plt.colorbar(cmap=plt.get_cmap("RdYlBu_r"),fraction=0.046, pad=0.04)
    if export_path:
        plt.savefig(export_path)
        plt.clf()
        plt.cla()
        plt.close()

    else:
        plt.show()

# %%
import os
os.mkdir("./saved_model_convlstm/fig/")
ch =['tas', 'psl', 'pr']

for i in range(98):
    visualize_2d_all(gt[i,:,0],pr[i,:,0], lon, lat, ch[1]+" "+str(i), export_path="./saved_model_convlstm/fig/"+ch[j]+"_"+str(i)+".png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/deepsphere/lib/python3.7/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     503     try:
# --> 504         fh = fp.fileno()
#     505         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hn/57__37595t3fdb1t0_66m7642mmx98/T/ipykernel_82342/2369136466.py in <module>
#       4
#       5 for i in range(98):
# ----> 6     visualize_2d_all(gt[i,:,0],pr[i,:,0], lon, lat, ch[1]+" "+str(i), export_path="./saved_model_convlstm/fig/"+ch[j]+"_"+str(i)+".png")
#
# /var/folders/hn/57__37595t3fdb1t0_66m7642mmx98/T/ipykernel_82342/2600131620.py in visualize_2d_all(gt, pr, longitude, latitude, title, export_path)
#      46     plt.colorbar(cmap=plt.get_cmap("RdYlBu_r"),fraction=0.046, pad=0.04)
#      47     if export_path:
# ---> 48         plt.savefig(export_path)
#      49         plt.clf()
#      50         plt.cla()
#
# ~/miniconda3/envs/deepsphere/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# ~/miniconda3/envs/deepsphere/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3017                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3018
# -> 3019             self.canvas.print_figure(fname, **kwargs)
#    3020
#    3021     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# ~/miniconda3/envs/deepsphere/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2323                         orientation=orientation,
#    2324                         bbox_inches_restore=_bbox_inches_restore,
# -> 2325                         **kwargs)
#    2326             finally:
#    2327                 if bbox_inches and restore_bbox:
#
# ~/miniconda3/envs/deepsphere/lib/python3.7/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# ~/miniconda3/envs/deepsphere/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# ~/miniconda3/envs/deepsphere/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
# --> 543             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#     544
#     545     def print_to_buffer(self):
#
# ~/miniconda3/envs/deepsphere/lib/python3.7/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673         pil_kwargs.setdefault("format", format)
#    1674         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675         image.save(fname, **pil_kwargs)
#    1676
#    1677
#
# ~/miniconda3/envs/deepsphere/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2238
#    2239         try:
# -> 2240             save_handler(self, fp, filename)
#    2241         finally:
#    2242             # do what we can to clean up
#
# ~/miniconda3/envs/deepsphere/lib/python3.7/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1346         _write_multiple_frames(im, fp, chunk, rawmode)
#    1347     else:
# -> 1348         ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1349
#    1350     if info:
#
# ~/miniconda3/envs/deepsphere/lib/python3.7/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     516             else:
#     517                 while True:
# --> 518                     l, s, d = e.encode(bufsize)
#     519                     fp.write(d)
#     520                     if s:
#
# KeyboardInterrupt:
