# %%
import numpy as np
from interpolate import *
import xarray as xr
import os

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import cartopy.crs as ccrs

import h5py

# %%
path = "/Users/sookim/aibedo/skeleton_framework/data/"

# %%
inn = xr.open_dataset(path+"Processed_CESM2_r1i1p1f1_historical_Input.nc")
out = xr.open_dataset(path+"Processed_CESM2_r1i1p1f1_historical_Output.nc")

# %%
inn
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1980, lat: 192, lon: 288)
# Coordinates:
#   * time     (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
# Data variables:
#     cres     (time, lat, lon) float32 ...
#     alpha    (time, lat, lon) float32 ...
#     clt      (time, lat, lon) float32 ...
#     clwvi    (time, lat, lon) float32 ...
#     clivi    (time, lat, lon) float32 ...

# %%
out
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1980, lat: 192, lon: 288)
# Coordinates:
#   * time     (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
# Data variables:
#     tas      (time, lat, lon) float32 ...
#     psl      (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...

# %%
inn.data_vars
# Out:
# Data variables:
#     cres     (time, lat, lon) float32 ...
#     alpha    (time, lat, lon) float32 ...
#     clt      (time, lat, lon) float32 ...
#     clwvi    (time, lat, lon) float32 ...
#     clivi    (time, lat, lon) float32 ...

# %%
inn_name = list(inn.data_vars)

# %%
a =np.asarray( inn[inn_name[0]])

# %%
print(np.shape(a))
# Out:
# (1980, 192, 288)

# %%
out_name = list(out.data_vars)

# %%
out_name
# Out:
# ['tas', 'psl', 'pr']

# %%
print(np.shape(out[out_name[0]]))
# Out:
# (1980, 192, 288)

# %%
inn.clt
# Out:
# <xarray.DataArray 'clt' (time: 1980, lat: 192, lon: 288)>
# [109486080 values with dtype=float32]
# Coordinates:
#   * time     (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
# Attributes:
#     long_name:  Total Cloud Cover Percentage
#     units:      %

# %%
inn['clt'].lon
# Out:
# <xarray.DataArray 'lon' (lon: 288)>
# array([  0.  ,   1.25,   2.5 , ..., 356.25, 357.5 , 358.75])
# Coordinates:
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
# Attributes:
#     axis:           X
#     bounds:         lon_bnds
#     standard_name:  longitude
#     title:          Longitude
#     type:           double
#     units:          degrees_east
#     valid_max:      360.0
#     valid_min:      0.0

# %%
np.asarray(inn['clt'].lon)
# Out:
# array([  0.  ,   1.25,   2.5 ,   3.75,   5.  ,   6.25,   7.5 ,   8.75,
#         10.  ,  11.25,  12.5 ,  13.75,  15.  ,  16.25,  17.5 ,  18.75,
#         20.  ,  21.25,  22.5 ,  23.75,  25.  ,  26.25,  27.5 ,  28.75,
#         30.  ,  31.25,  32.5 ,  33.75,  35.  ,  36.25,  37.5 ,  38.75,
#         40.  ,  41.25,  42.5 ,  43.75,  45.  ,  46.25,  47.5 ,  48.75,
#         50.  ,  51.25,  52.5 ,  53.75,  55.  ,  56.25,  57.5 ,  58.75,
#         60.  ,  61.25,  62.5 ,  63.75,  65.  ,  66.25,  67.5 ,  68.75,
#         70.  ,  71.25,  72.5 ,  73.75,  75.  ,  76.25,  77.5 ,  78.75,
#         80.  ,  81.25,  82.5 ,  83.75,  85.  ,  86.25,  87.5 ,  88.75,
#         90.  ,  91.25,  92.5 ,  93.75,  95.  ,  96.25,  97.5 ,  98.75,
#        100.  , 101.25, 102.5 , 103.75, 105.  , 106.25, 107.5 , 108.75,
#        110.  , 111.25, 112.5 , 113.75, 115.  , 116.25, 117.5 , 118.75,
#        120.  , 121.25, 122.5 , 123.75, 125.  , 126.25, 127.5 , 128.75,
# ...
